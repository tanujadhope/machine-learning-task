# %%
import pandas as pd
import numpy as np
df=pd.read_csv("https://raw.githubusercontent.com/shrikant-temburwar/Wine-Quality-Dataset/master/winequality-red.csv",sep = ';')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
len(df['quality'].unique())
# Out:
# 6

# %%
df['quality'].nunique()
# Out:
# 6

# %%
df['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
df.describe().T
# Out:
#                        count       mean        std      min      25%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   7.1000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.3900
# citric acid           1599.0   0.270976   0.194801  0.00000   0.0900
# residual sugar        1599.0   2.538806   1.409928  0.90000   1.9000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.0700
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   7.0000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  22.0000
# density               1599.0   0.996747   0.001887  0.99007   0.9956
# pH                    1599.0   3.311113   0.154386  2.74000   3.2100
# sulphates             1599.0   0.658149   0.169507  0.33000   0.5500
# alcohol               1599.0  10.422983   1.065668  8.40000   9.5000
# quality               1599.0   5.636023   0.807569  3.00000   5.0000
#
#                            50%        75%        max
# fixed acidity          7.90000   9.200000   15.90000
# volatile acidity       0.52000   0.640000    1.58000
# citric acid            0.26000   0.420000    1.00000
# residual sugar         2.20000   2.600000   15.50000
# chlorides              0.07900   0.090000    0.61100
# free sulfur dioxide   14.00000  21.000000   72.00000
# total sulfur dioxide  38.00000  62.000000  289.00000
# density                0.99675   0.997835    1.00369
# pH                     3.31000   3.400000    4.01000
# sulphates              0.62000   0.730000    2.00000
# alcohol               10.20000  11.100000   14.90000
# quality                6.00000   6.000000    8.00000

# %%
df.duplicated().sum()
# Out:
# 240

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
demo_df=pd.DataFrame([1,2,3,3,23,2,1,2,123,333])

# %%
demo_df
# Out:
#      0
# 0    1
# 1    2
# 2    3
# 3    3
# 4   23
# 5    2
# 6    1
# 7    2
# 8  123
# 9  333

# %%
demo_df.duplicated().sum()
# Out:
# 4

# %%
X=df.drop("quality",axis=1)

# %%
y=df['quality']

# %%
from sklearn.model_selection import train_test_split,GridSearchCV

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.33,random_state=10)

# %%
'''from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import StandardScaler
sclr = StandardScaler()
scr.fit()
scr.transform()'''
# Out:
# 'from sklearn.preprocessing import StandardScaler\nfrom sklearn.preprocessing import StandardScaler\nsclr = StandardScaler()\nscr.fit()\nscr.transform()'

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.score(X_train,y_train)
# Out:
# 1.0

# %%
from sklearn import tree
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(25,15))
tree.plot_tree(model,filled=True)
# Out:
# [Text(0.4911862080103359, 0.9705882352941176, 'X[10] <= 10.15\ngini = 0.645\nsamples = 910\nvalue = [7, 31, 389, 359, 114, 10]'),
#  Text(0.22428940568475453, 0.9117647058823529, 'X[6] <= 62.5\ngini = 0.495\nsamples = 459\nvalue = [3, 15, 298, 131, 12, 0]'),
#  Text(0.1148578811369509, 0.8529411764705882, 'X[1] <= 0.548\ngini = 0.571\nsamples = 282\nvalue = [3, 11, 151, 105, 12, 0]'),
#  Text(0.05910852713178295, 0.7941176470588235, 'X[9] <= 0.585\ngini = 0.596\nsamples = 136\nvalue = [1, 4, 52, 68, 11, 0]'),
#  Text(0.020671834625323, 0.7352941176470589, 'X[7] <= 0.996\ngini = 0.512\nsamples = 44\nvalue = [0, 4, 28, 12, 0, 0]'),
#  Text(0.008268733850129198, 0.6764705882352942, 'X[9] <= 0.435\ngini = 0.245\nsamples = 14\nvalue = [0, 2, 12, 0, 0, 0]'),
#  Text(0.004134366925064599, 0.6176470588235294, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.012403100775193798, 0.6176470588235294, 'X[8] <= 3.425\ngini = 0.142\nsamples = 13\nvalue = [0, 1, 12, 0, 0, 0]'),
#  Text(0.008268733850129198, 0.5588235294117647, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 11, 0, 0, 0]'),
#  Text(0.016537467700258397, 0.5588235294117647, 'X[9] <= 0.56\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.012403100775193798, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.020671834625323, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.03307493540051679, 0.6764705882352942, 'X[7] <= 0.996\ngini = 0.551\nsamples = 30\nvalue = [0, 2, 16, 12, 0, 0]'),
#  Text(0.028940568475452195, 0.6176470588235294, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.037209302325581395, 0.6176470588235294, 'X[6] <= 59.0\ngini = 0.532\nsamples = 27\nvalue = [0, 2, 16, 9, 0, 0]'),
#  Text(0.03307493540051679, 0.5588235294117647, 'X[3] <= 3.9\ngini = 0.506\nsamples = 25\nvalue = [0, 2, 16, 7, 0, 0]'),
#  Text(0.028940568475452195, 0.5, 'X[3] <= 1.95\ngini = 0.469\nsamples = 24\nvalue = [0, 1, 16, 7, 0, 0]'),
#  Text(0.024806201550387597, 0.4411764705882353, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.03307493540051679, 0.4411764705882353, 'X[10] <= 9.05\ngini = 0.526\nsamples = 19\nvalue = [0, 1, 11, 7, 0, 0]'),
#  Text(0.028940568475452195, 0.38235294117647056, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.037209302325581395, 0.38235294117647056, 'X[0] <= 10.65\ngini = 0.491\nsamples = 17\nvalue = [0, 1, 11, 5, 0, 0]'),
#  Text(0.03307493540051679, 0.3235294117647059, 'X[2] <= 0.15\ngini = 0.569\nsamples = 12\nvalue = [0, 1, 6, 5, 0, 0]'),
#  Text(0.028940568475452195, 0.2647058823529412, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.037209302325581395, 0.2647058823529412, 'X[7] <= 0.998\ngini = 0.568\nsamples = 9\nvalue = [0, 1, 3, 5, 0, 0]'),
#  Text(0.03307493540051679, 0.20588235294117646, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.041343669250646, 0.20588235294117646, 'X[1] <= 0.47\ngini = 0.56\nsamples = 5\nvalue = [0, 1, 3, 1, 0, 0]'),
#  Text(0.037209302325581395, 0.14705882352941177, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.04547803617571059, 0.14705882352941177, 'X[5] <= 9.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.041343669250646, 0.08823529411764706, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.04961240310077519, 0.08823529411764706, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.041343669250646, 0.3235294117647059, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.037209302325581395, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.041343669250646, 0.5588235294117647, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.09754521963824289, 0.7352941176470589, 'X[7] <= 0.996\ngini = 0.547\nsamples = 92\nvalue = [1, 0, 24, 56, 11, 0]'),
#  Text(0.0934108527131783, 0.6764705882352942, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.1016795865633075, 0.6764705882352942, 'X[0] <= 11.35\ngini = 0.532\nsamples = 90\nvalue = [1, 0, 24, 56, 9, 0]'),
#  Text(0.0834625322997416, 0.6176470588235294, 'X[10] <= 9.95\ngini = 0.533\nsamples = 75\nvalue = [1, 0, 24, 45, 5, 0]'),
#  Text(0.059431524547803614, 0.5588235294117647, 'X[9] <= 0.615\ngini = 0.531\nsamples = 60\nvalue = [1, 0, 23, 34, 2, 0]'),
#  Text(0.04547803617571059, 0.5, 'X[10] <= 9.6\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 0, 6, 1, 0]'),
#  Text(0.041343669250646, 0.4411764705882353, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.04961240310077519, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.07338501291989664, 0.5, 'X[9] <= 0.645\ngini = 0.532\nsamples = 53\nvalue = [1, 0, 23, 28, 1, 0]'),
#  Text(0.05788113695090439, 0.4411764705882353, 'X[8] <= 3.395\ngini = 0.461\nsamples = 16\nvalue = [0, 0, 11, 4, 1, 0]'),
#  Text(0.053746770025839795, 0.38235294117647056, 'X[4] <= 0.164\ngini = 0.357\nsamples = 14\nvalue = [0, 0, 11, 2, 1, 0]'),
#  Text(0.04961240310077519, 0.3235294117647059, 'X[1] <= 0.51\ngini = 0.153\nsamples = 12\nvalue = [0, 0, 11, 0, 1, 0]'),
#  Text(0.04547803617571059, 0.2647058823529412, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 10, 0, 0, 0]'),
#  Text(0.053746770025839795, 0.2647058823529412, 'X[3] <= 2.1\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(0.04961240310077519, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.05788113695090439, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.05788113695090439, 0.3235294117647059, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.06201550387596899, 0.38235294117647056, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.08888888888888889, 0.4411764705882353, 'X[4] <= 0.084\ngini = 0.473\nsamples = 37\nvalue = [1, 0, 12, 24, 0, 0]'),
#  Text(0.07441860465116279, 0.38235294117647056, 'X[5] <= 22.5\ngini = 0.278\nsamples = 18\nvalue = [0, 0, 3, 15, 0, 0]'),
#  Text(0.06614987080103359, 0.3235294117647059, 'X[2] <= 0.57\ngini = 0.124\nsamples = 15\nvalue = [0, 0, 1, 14, 0, 0]'),
#  Text(0.06201550387596899, 0.2647058823529412, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 0, 14, 0, 0]'),
#  Text(0.0702842377260982, 0.2647058823529412, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.082687338501292, 0.3235294117647059, 'X[3] <= 2.2\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.07855297157622738, 0.2647058823529412, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.08682170542635659, 0.2647058823529412, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.10335917312661498, 0.38235294117647056, 'X[7] <= 0.998\ngini = 0.548\nsamples = 19\nvalue = [1, 0, 9, 9, 0, 0]'),
#  Text(0.09922480620155039, 0.3235294117647059, 'X[0] <= 7.6\ngini = 0.524\nsamples = 15\nvalue = [1, 0, 5, 9, 0, 0]'),
#  Text(0.09509043927648579, 0.2647058823529412, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.10335917312661498, 0.2647058823529412, 'X[9] <= 1.09\ngini = 0.403\nsamples = 12\nvalue = [1, 0, 2, 9, 0, 0]'),
#  Text(0.09922480620155039, 0.20588235294117646, 'X[3] <= 1.6\ngini = 0.18\nsamples = 10\nvalue = [1, 0, 0, 9, 0, 0]'),
#  Text(0.09509043927648579, 0.14705882352941177, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.10335917312661498, 0.14705882352941177, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9, 0, 0]'),
#  Text(0.10749354005167959, 0.20588235294117646, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.10749354005167959, 0.3235294117647059, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.10749354005167959, 0.5588235294117647, 'X[6] <= 46.5\ngini = 0.418\nsamples = 15\nvalue = [0, 0, 1, 11, 3, 0]'),
#  Text(0.10335917312661498, 0.5, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(0.11162790697674418, 0.5, 'X[3] <= 2.65\ngini = 0.56\nsamples = 5\nvalue = [0, 0, 1, 1, 3, 0]'),
#  Text(0.10749354005167959, 0.4411764705882353, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.11576227390180878, 0.4411764705882353, 'X[4] <= 0.088\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.11162790697674418, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.11989664082687339, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.11989664082687339, 0.6176470588235294, 'X[5] <= 8.0\ngini = 0.391\nsamples = 15\nvalue = [0, 0, 0, 11, 4, 0]'),
#  Text(0.11576227390180878, 0.5588235294117647, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(0.12403100775193798, 0.5588235294117647, 'X[1] <= 0.295\ngini = 0.49\nsamples = 7\nvalue = [0, 0, 0, 3, 4, 0]'),
#  Text(0.11989664082687339, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.1281653746770026, 0.5, 'X[3] <= 1.85\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 3, 1, 0]'),
#  Text(0.12403100775193798, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.13229974160206717, 0.4411764705882353, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.17060723514211887, 0.7941176470588235, 'X[7] <= 0.996\ngini = 0.473\nsamples = 146\nvalue = [2, 7, 99, 37, 1, 0]'),
#  Text(0.1405684754521964, 0.7352941176470589, 'X[10] <= 9.15\ngini = 0.176\nsamples = 32\nvalue = [1, 1, 29, 1, 0, 0]'),
#  Text(0.13229974160206717, 0.6764705882352942, 'X[7] <= 0.996\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.1281653746770026, 0.6176470588235294, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.13643410852713178, 0.6176470588235294, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.14883720930232558, 0.6764705882352942, 'X[8] <= 3.515\ngini = 0.064\nsamples = 30\nvalue = [1, 0, 29, 0, 0, 0]'),
#  Text(0.14470284237726097, 0.6176470588235294, 'gini = 0.0\nsamples = 28\nvalue = [0, 0, 28, 0, 0, 0]'),
#  Text(0.1529715762273902, 0.6176470588235294, 'X[9] <= 0.575\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1, 0, 0, 0]'),
#  Text(0.14883720930232558, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.15710594315245477, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.20064599483204135, 0.7352941176470589, 'X[10] <= 9.95\ngini = 0.52\nsamples = 114\nvalue = [1, 6, 70, 36, 1, 0]'),
#  Text(0.1806201550387597, 0.6764705882352942, 'X[8] <= 3.195\ngini = 0.487\nsamples = 95\nvalue = [1, 6, 63, 25, 0, 0]'),
#  Text(0.17648578811369509, 0.6176470588235294, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 10, 0, 0, 0]'),
#  Text(0.1847545219638243, 0.6176470588235294, 'X[1] <= 0.688\ngini = 0.52\nsamples = 85\nvalue = [1, 6, 53, 25, 0, 0]'),
#  Text(0.165374677002584, 0.5588235294117647, 'X[2] <= 0.28\ngini = 0.544\nsamples = 54\nvalue = [1, 2, 29, 22, 0, 0]'),
#  Text(0.15348837209302327, 0.5, 'X[9] <= 0.535\ngini = 0.491\nsamples = 51\nvalue = [0, 0, 29, 22, 0, 0]'),
#  Text(0.1421188630490956, 0.4411764705882353, 'X[8] <= 3.21\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 7, 1, 0, 0]'),
#  Text(0.13798449612403102, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.1462532299741602, 0.38235294117647056, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.1648578811369509, 0.4411764705882353, 'X[2] <= 0.17\ngini = 0.5\nsamples = 43\nvalue = [0, 0, 22, 21, 0, 0]'),
#  Text(0.1545219638242894, 0.38235294117647056, 'X[0] <= 6.95\ngini = 0.489\nsamples = 33\nvalue = [0, 0, 14, 19, 0, 0]'),
#  Text(0.1462532299741602, 0.3235294117647059, 'X[7] <= 0.997\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 5, 1, 0, 0]'),
#  Text(0.1421188630490956, 0.2647058823529412, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.15038759689922482, 0.2647058823529412, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.16279069767441862, 0.3235294117647059, 'X[7] <= 0.997\ngini = 0.444\nsamples = 27\nvalue = [0, 0, 9, 18, 0, 0]'),
#  Text(0.158656330749354, 0.2647058823529412, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(0.1669250645994832, 0.2647058823529412, 'X[0] <= 7.25\ngini = 0.498\nsamples = 17\nvalue = [0, 0, 9, 8, 0, 0]'),
#  Text(0.16279069767441862, 0.20588235294117646, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.1710594315245478, 0.20588235294117646, 'X[8] <= 3.3\ngini = 0.473\nsamples = 13\nvalue = [0, 0, 5, 8, 0, 0]'),
#  Text(0.1669250645994832, 0.14705882352941177, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.17519379844961241, 0.14705882352941177, 'X[4] <= 0.077\ngini = 0.397\nsamples = 11\nvalue = [0, 0, 3, 8, 0, 0]'),
#  Text(0.1710594315245478, 0.08823529411764706, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.179328165374677, 0.08823529411764706, 'X[6] <= 11.5\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 1, 8, 0, 0]'),
#  Text(0.17519379844961241, 0.029411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.1834625322997416, 0.029411764705882353, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(0.17519379844961241, 0.38235294117647056, 'X[1] <= 0.555\ngini = 0.32\nsamples = 10\nvalue = [0, 0, 8, 2, 0, 0]'),
#  Text(0.1710594315245478, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.179328165374677, 0.3235294117647059, 'X[6] <= 61.0\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 8, 1, 0, 0]'),
#  Text(0.17519379844961241, 0.2647058823529412, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 8, 0, 0, 0]'),
#  Text(0.1834625322997416, 0.2647058823529412, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.1772609819121447, 0.5, 'X[9] <= 0.565\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0, 0, 0, 0]'),
#  Text(0.1731266149870801, 0.4411764705882353, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.1813953488372093, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.2041343669250646, 0.5588235294117647, 'X[9] <= 0.465\ngini = 0.375\nsamples = 31\nvalue = [0, 4, 24, 3, 0, 0]'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.2082687338501292, 0.5, 'X[0] <= 8.75\ngini = 0.3\nsamples = 29\nvalue = [0, 2, 24, 3, 0, 0]'),
#  Text(0.1958656330749354, 0.4411764705882353, 'X[4] <= 0.065\ngini = 0.15\nsamples = 25\nvalue = [0, 1, 23, 1, 0, 0]'),
#  Text(0.1917312661498708, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.2, 0.38235294117647056, 'X[6] <= 12.5\ngini = 0.08\nsamples = 24\nvalue = [0, 1, 23, 0, 0, 0]'),
#  Text(0.1958656330749354, 0.3235294117647059, 'X[0] <= 7.55\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.1917312661498708, 0.2647058823529412, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.2, 0.2647058823529412, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.2041343669250646, 0.3235294117647059, 'gini = 0.0\nsamples = 22\nvalue = [0, 0, 22, 0, 0, 0]'),
#  Text(0.220671834625323, 0.4411764705882353, 'X[3] <= 2.45\ngini = 0.625\nsamples = 4\nvalue = [0, 1, 1, 2, 0, 0]'),
#  Text(0.2165374677002584, 0.38235294117647056, 'X[0] <= 9.05\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.2124031007751938, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.220671834625323, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.2248062015503876, 0.38235294117647056, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.220671834625323, 0.6764705882352942, 'X[7] <= 0.997\ngini = 0.526\nsamples = 19\nvalue = [0, 0, 7, 11, 1, 0]'),
#  Text(0.2165374677002584, 0.6176470588235294, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.2248062015503876, 0.6176470588235294, 'X[7] <= 0.998\ngini = 0.556\nsamples = 13\nvalue = [0, 0, 7, 5, 1, 0]'),
#  Text(0.220671834625323, 0.5588235294117647, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.2289405684754522, 0.5588235294117647, 'X[7] <= 0.999\ngini = 0.531\nsamples = 8\nvalue = [0, 0, 2, 5, 1, 0]'),
#  Text(0.2248062015503876, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.2330749354005168, 0.5, 'X[9] <= 0.725\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 0, 1, 0]'),
#  Text(0.2289405684754522, 0.4411764705882353, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.2372093023255814, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.33372093023255817, 0.8529411764705882, 'X[6] <= 98.5\ngini = 0.288\nsamples = 177\nvalue = [0, 4, 147, 26, 0, 0]'),
#  Text(0.29483204134366925, 0.7941176470588235, 'X[10] <= 9.45\ngini = 0.39\nsamples = 116\nvalue = [0, 4, 87, 25, 0, 0]'),
#  Text(0.2661498708010336, 0.7352941176470589, 'X[8] <= 3.495\ngini = 0.222\nsamples = 49\nvalue = [0, 2, 43, 4, 0, 0]'),
#  Text(0.25788113695090437, 0.6764705882352942, 'X[2] <= 0.84\ngini = 0.163\nsamples = 46\nvalue = [0, 2, 42, 2, 0, 0]'),
#  Text(0.2537467700258398, 0.6176470588235294, 'X[5] <= 7.0\ngini = 0.126\nsamples = 45\nvalue = [0, 1, 42, 2, 0, 0]'),
#  Text(0.2496124031007752, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.25788113695090437, 0.5588235294117647, 'X[2] <= 0.09\ngini = 0.088\nsamples = 44\nvalue = [0, 1, 42, 1, 0, 0]'),
#  Text(0.2496124031007752, 0.5, 'X[8] <= 3.31\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.2454780361757106, 0.4411764705882353, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.2537467700258398, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.2661498708010336, 0.5, 'X[5] <= 11.5\ngini = 0.048\nsamples = 41\nvalue = [0, 1, 40, 0, 0, 0]'),
#  Text(0.262015503875969, 0.4411764705882353, 'X[10] <= 9.3\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2, 0, 0, 0]'),
#  Text(0.25788113695090437, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.2661498708010336, 0.38235294117647056, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.27028423772609816, 0.4411764705882353, 'gini = 0.0\nsamples = 38\nvalue = [0, 0, 38, 0, 0, 0]'),
#  Text(0.262015503875969, 0.6176470588235294, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.2744186046511628, 0.6764705882352942, 'X[5] <= 13.5\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.27028423772609816, 0.6176470588235294, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.2785529715762274, 0.6176470588235294, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.3235142118863049, 0.7352941176470589, 'X[1] <= 0.415\ngini = 0.47\nsamples = 67\nvalue = [0, 2, 44, 21, 0, 0]'),
#  Text(0.2909560723514212, 0.6764705882352942, 'X[1] <= 0.325\ngini = 0.5\nsamples = 14\nvalue = [0, 1, 4, 9, 0, 0]'),
#  Text(0.2868217054263566, 0.6176470588235294, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.29509043927648576, 0.6176470588235294, 'X[7] <= 0.998\ngini = 0.403\nsamples = 12\nvalue = [0, 1, 2, 9, 0, 0]'),
#  Text(0.2868217054263566, 0.5588235294117647, 'X[6] <= 82.0\ngini = 0.198\nsamples = 9\nvalue = [0, 1, 0, 8, 0, 0]'),
#  Text(0.28268733850129196, 0.5, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(0.2909560723514212, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.303359173126615, 0.5588235294117647, 'X[1] <= 0.355\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.2992248062015504, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.30749354005167956, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.35607235142118865, 0.6764705882352942, 'X[8] <= 3.295\ngini = 0.379\nsamples = 53\nvalue = [0, 1, 40, 12, 0, 0]'),
#  Text(0.3343669250645995, 0.6176470588235294, 'X[8] <= 3.205\ngini = 0.5\nsamples = 26\nvalue = [0, 1, 16, 9, 0, 0]'),
#  Text(0.31989664082687336, 0.5588235294117647, 'X[3] <= 2.85\ngini = 0.26\nsamples = 13\nvalue = [0, 0, 11, 2, 0, 0]'),
#  Text(0.3157622739018088, 0.5, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 10, 0, 0, 0]'),
#  Text(0.324031007751938, 0.5, 'X[0] <= 7.0\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.31989664082687336, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3281653746770026, 0.4411764705882353, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.3488372093023256, 0.5588235294117647, 'X[7] <= 0.997\ngini = 0.556\nsamples = 13\nvalue = [0, 1, 5, 7, 0, 0]'),
#  Text(0.3405684754521964, 0.5, 'X[10] <= 9.7\ngini = 0.278\nsamples = 6\nvalue = [0, 1, 0, 5, 0, 0]'),
#  Text(0.3364341085271318, 0.4411764705882353, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.344702842377261, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.3571059431524548, 0.5, 'X[6] <= 75.0\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 5, 2, 0, 0]'),
#  Text(0.35297157622739017, 0.4411764705882353, 'X[3] <= 2.75\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.3488372093023256, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3571059431524548, 0.38235294117647056, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.3612403100775194, 0.4411764705882353, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.37777777777777777, 0.6176470588235294, 'X[2] <= 0.025\ngini = 0.198\nsamples = 27\nvalue = [0, 0, 24, 3, 0, 0]'),
#  Text(0.3695090439276486, 0.5588235294117647, 'X[10] <= 9.75\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 2, 0, 0]'),
#  Text(0.36537467700258397, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.3736434108527132, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.386046511627907, 0.5588235294117647, 'X[6] <= 97.0\ngini = 0.087\nsamples = 22\nvalue = [0, 0, 21, 1, 0, 0]'),
#  Text(0.3819121447028424, 0.5, 'gini = 0.0\nsamples = 19\nvalue = [0, 0, 19, 0, 0, 0]'),
#  Text(0.39018087855297157, 0.5, 'X[3] <= 2.75\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.386046511627907, 0.4411764705882353, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.3943152454780362, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.37260981912144703, 0.7941176470588235, 'X[4] <= 0.067\ngini = 0.032\nsamples = 61\nvalue = [0, 0, 60, 1, 0, 0]'),
#  Text(0.36847545219638245, 0.7352941176470589, 'X[10] <= 9.45\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.3643410852713178, 0.6764705882352942, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.37260981912144703, 0.6764705882352942, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3767441860465116, 0.7352941176470589, 'gini = 0.0\nsamples = 59\nvalue = [0, 0, 59, 0, 0, 0]'),
#  Text(0.7580830103359173, 0.9117647058823529, 'X[9] <= 0.675\ngini = 0.651\nsamples = 451\nvalue = [4, 16, 91, 228, 102, 10]'),
#  Text(0.6060077519379845, 0.8529411764705882, 'X[10] <= 11.45\ngini = 0.636\nsamples = 250\nvalue = [4, 16, 69, 130, 29, 2]'),
#  Text(0.522093023255814, 0.7941176470588235, 'X[1] <= 0.827\ngini = 0.649\nsamples = 157\nvalue = [4, 13, 60, 69, 10, 1]'),
#  Text(0.44935400516795865, 0.7352941176470589, 'X[3] <= 1.85\ngini = 0.589\nsamples = 134\nvalue = [0, 3, 54, 66, 10, 1]'),
#  Text(0.41498708010335916, 0.6764705882352942, 'X[8] <= 3.355\ngini = 0.544\nsamples = 26\nvalue = [0, 0, 16, 6, 4, 0]'),
#  Text(0.40671834625323, 0.6176470588235294, 'X[2] <= 0.405\ngini = 0.661\nsamples = 11\nvalue = [0, 0, 3, 4, 4, 0]'),
#  Text(0.40258397932816536, 0.5588235294117647, 'X[5] <= 15.0\ngini = 0.5\nsamples = 8\nvalue = [0, 0, 0, 4, 4, 0]'),
#  Text(0.3984496124031008, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(0.40671834625323, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.4108527131782946, 0.5588235294117647, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.4232558139534884, 0.6176470588235294, 'X[8] <= 3.4\ngini = 0.231\nsamples = 15\nvalue = [0, 0, 13, 2, 0, 0]'),
#  Text(0.4191214470284238, 0.5588235294117647, 'X[4] <= 0.074\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 4, 2, 0, 0]'),
#  Text(0.41498708010335916, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.4232558139534884, 0.5, 'X[8] <= 3.365\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.4191214470284238, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.42739018087855296, 0.4411764705882353, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.42739018087855296, 0.5588235294117647, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 9, 0, 0, 0]'),
#  Text(0.48372093023255813, 0.6764705882352942, 'X[7] <= 0.996\ngini = 0.564\nsamples = 108\nvalue = [0, 3, 38, 60, 6, 1]'),
#  Text(0.43979328165374676, 0.6176470588235294, 'X[9] <= 0.525\ngini = 0.373\nsamples = 38\nvalue = [0, 0, 8, 29, 1, 0]'),
#  Text(0.4356589147286822, 0.5588235294117647, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.4439276485788114, 0.5588235294117647, 'X[6] <= 9.0\ngini = 0.292\nsamples = 35\nvalue = [0, 0, 5, 29, 1, 0]'),
#  Text(0.43979328165374676, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.448062015503876, 0.5, 'X[7] <= 0.995\ngini = 0.251\nsamples = 34\nvalue = [0, 0, 5, 29, 0, 0]'),
#  Text(0.4377260981912145, 0.4411764705882353, 'X[8] <= 3.345\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 2, 0, 0]'),
#  Text(0.43359173126614986, 0.38235294117647056, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.4418604651162791, 0.38235294117647056, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.45839793281653746, 0.4411764705882353, 'X[5] <= 7.0\ngini = 0.18\nsamples = 30\nvalue = [0, 0, 3, 27, 0, 0]'),
#  Text(0.4501291989664083, 0.38235294117647056, 'X[4] <= 0.096\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 2, 4, 0, 0]'),
#  Text(0.44599483204134366, 0.3235294117647059, 'X[3] <= 2.25\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.4418604651162791, 0.2647058823529412, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.4501291989664083, 0.2647058823529412, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.4542635658914729, 0.3235294117647059, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.4666666666666667, 0.38235294117647056, 'X[6] <= 26.5\ngini = 0.08\nsamples = 24\nvalue = [0, 0, 1, 23, 0, 0]'),
#  Text(0.4625322997416021, 0.3235294117647059, 'X[8] <= 3.355\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 1, 4, 0, 0]'),
#  Text(0.45839793281653746, 0.2647058823529412, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.4666666666666667, 0.2647058823529412, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.47080103359173125, 0.3235294117647059, 'gini = 0.0\nsamples = 19\nvalue = [0, 0, 0, 19, 0, 0]'),
#  Text(0.5276485788113695, 0.6176470588235294, 'X[6] <= 42.5\ngini = 0.613\nsamples = 70\nvalue = [0, 3, 30, 31, 5, 1]'),
#  Text(0.5059431524547804, 0.5588235294117647, 'X[3] <= 2.15\ngini = 0.629\nsamples = 46\nvalue = [0, 2, 23, 15, 5, 1]'),
#  Text(0.49767441860465117, 0.5, 'X[9] <= 0.66\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 1, 5, 0, 0]'),
#  Text(0.4935400516795866, 0.4411764705882353, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.5018087855297158, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.5142118863049095, 0.5, 'X[1] <= 0.78\ngini = 0.616\nsamples = 40\nvalue = [0, 2, 22, 10, 5, 1]'),
#  Text(0.5100775193798449, 0.4411764705882353, 'X[10] <= 10.55\ngini = 0.6\nsamples = 38\nvalue = [0, 2, 22, 8, 5, 1]'),
#  Text(0.4873385012919897, 0.38235294117647056, 'X[6] <= 37.5\ngini = 0.32\nsamples = 16\nvalue = [0, 0, 13, 2, 1, 0]'),
#  Text(0.4790697674418605, 0.3235294117647059, 'X[8] <= 3.485\ngini = 0.142\nsamples = 13\nvalue = [0, 0, 12, 0, 1, 0]'),
#  Text(0.4749354005167959, 0.2647058823529412, 'gini = 0.0\nsamples = 12\nvalue = [0, 0, 12, 0, 0, 0]'),
#  Text(0.48320413436692505, 0.2647058823529412, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.49560723514211885, 0.3235294117647059, 'X[6] <= 41.5\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.49147286821705427, 0.2647058823529412, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.4997416020671835, 0.2647058823529412, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.5328165374677003, 0.38235294117647056, 'X[9] <= 0.625\ngini = 0.715\nsamples = 22\nvalue = [0, 2, 9, 6, 4, 1]'),
#  Text(0.5162790697674419, 0.3235294117647059, 'X[4] <= 0.081\ngini = 0.602\nsamples = 16\nvalue = [0, 1, 8, 6, 1, 0]'),
#  Text(0.5080103359173127, 0.2647058823529412, 'X[7] <= 0.996\ngini = 0.449\nsamples = 7\nvalue = [0, 1, 5, 0, 1, 0]'),
#  Text(0.5038759689922481, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.5121447028423772, 0.20588235294117646, 'X[6] <= 11.0\ngini = 0.278\nsamples = 6\nvalue = [0, 1, 5, 0, 0, 0]'),
#  Text(0.5080103359173127, 0.14705882352941177, 'X[6] <= 8.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.5038759689922481, 0.08823529411764706, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.5121447028423772, 0.08823529411764706, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.5162790697674419, 0.14705882352941177, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.524547803617571, 0.2647058823529412, 'X[4] <= 0.094\ngini = 0.444\nsamples = 9\nvalue = [0, 0, 3, 6, 0, 0]'),
#  Text(0.5204134366925065, 0.20588235294117646, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.5286821705426357, 0.20588235294117646, 'X[9] <= 0.565\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 2, 0, 0]'),
#  Text(0.524547803617571, 0.14705882352941177, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.5328165374677003, 0.14705882352941177, 'X[7] <= 0.999\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.5286821705426357, 0.08823529411764706, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.5369509043927648, 0.08823529411764706, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.5493540051679586, 0.3235294117647059, 'X[8] <= 3.165\ngini = 0.667\nsamples = 6\nvalue = [0, 1, 1, 0, 3, 1]'),
#  Text(0.5410852713178295, 0.2647058823529412, 'X[0] <= 10.45\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 0, 1]'),
#  Text(0.5369509043927648, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.5452196382428941, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.5576227390180879, 0.2647058823529412, 'X[5] <= 13.0\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 0, 0, 3, 0]'),
#  Text(0.5534883720930233, 0.20588235294117646, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.5617571059431524, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.5183462532299742, 0.4411764705882353, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.5493540051679586, 0.5588235294117647, 'X[3] <= 2.05\ngini = 0.469\nsamples = 24\nvalue = [0, 1, 7, 16, 0, 0]'),
#  Text(0.5410852713178295, 0.5, 'X[6] <= 54.5\ngini = 0.32\nsamples = 5\nvalue = [0, 1, 4, 0, 0, 0]'),
#  Text(0.5369509043927648, 0.4411764705882353, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.5452196382428941, 0.4411764705882353, 'X[7] <= 0.997\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.5410852713178295, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.5493540051679586, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.5576227390180879, 0.5, 'X[5] <= 27.5\ngini = 0.266\nsamples = 19\nvalue = [0, 0, 3, 16, 0, 0]'),
#  Text(0.5534883720930233, 0.4411764705882353, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 0, 14, 0, 0]'),
#  Text(0.5617571059431524, 0.4411764705882353, 'X[3] <= 2.85\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 2, 0, 0]'),
#  Text(0.5576227390180879, 0.38235294117647056, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.5658914728682171, 0.38235294117647056, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.5948320413436693, 0.7352941176470589, 'X[10] <= 10.95\ngini = 0.696\nsamples = 23\nvalue = [4, 10, 6, 3, 0, 0]'),
#  Text(0.5782945736434109, 0.6764705882352942, 'X[4] <= 0.075\ngini = 0.722\nsamples = 13\nvalue = [3, 2, 5, 3, 0, 0]'),
#  Text(0.5658914728682171, 0.6176470588235294, 'X[1] <= 0.905\ngini = 0.48\nsamples = 5\nvalue = [0, 2, 0, 3, 0, 0]'),
#  Text(0.5617571059431524, 0.5588235294117647, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.5700258397932817, 0.5588235294117647, 'X[9] <= 0.455\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 0, 1, 0, 0]'),
#  Text(0.5658914728682171, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.5741602067183462, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.5906976744186047, 0.6176470588235294, 'X[3] <= 3.275\ngini = 0.469\nsamples = 8\nvalue = [3, 0, 5, 0, 0, 0]'),
#  Text(0.58656330749354, 0.5588235294117647, 'X[9] <= 0.435\ngini = 0.278\nsamples = 6\nvalue = [1, 0, 5, 0, 0, 0]'),
#  Text(0.5824289405684755, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.5906976744186047, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.5948320413436693, 0.5588235294117647, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0, 0]'),
#  Text(0.6113695090439276, 0.6764705882352942, 'X[2] <= 0.255\ngini = 0.34\nsamples = 10\nvalue = [1, 8, 1, 0, 0, 0]'),
#  Text(0.6072351421188631, 0.6176470588235294, 'X[6] <= 11.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8, 0, 0, 0, 0]'),
#  Text(0.6031007751937985, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.6113695090439276, 0.5588235294117647, 'gini = 0.0\nsamples = 8\nvalue = [0, 8, 0, 0, 0, 0]'),
#  Text(0.6155038759689923, 0.6176470588235294, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.689922480620155, 0.7941176470588235, 'X[3] <= 4.5\ngini = 0.518\nsamples = 93\nvalue = [0, 3, 9, 61, 19, 1]'),
#  Text(0.6609819121447028, 0.7352941176470589, 'X[6] <= 15.5\ngini = 0.442\nsamples = 80\nvalue = [0, 1, 8, 58, 12, 1]'),
#  Text(0.6341085271317829, 0.6764705882352942, 'X[9] <= 0.545\ngini = 0.626\nsamples = 19\nvalue = [0, 1, 2, 9, 7, 0]'),
#  Text(0.6237726098191214, 0.6176470588235294, 'X[10] <= 12.6\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 1, 6, 0, 0]'),
#  Text(0.6196382428940569, 0.5588235294117647, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.627906976744186, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.6444444444444445, 0.6176470588235294, 'X[7] <= 0.995\ngini = 0.583\nsamples = 12\nvalue = [0, 1, 1, 3, 7, 0]'),
#  Text(0.6361757105943152, 0.5588235294117647, 'X[3] <= 2.45\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 1, 0, 6, 0]'),
#  Text(0.6320413436692507, 0.5, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 0, 6, 0]'),
#  Text(0.6403100775193798, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.6527131782945736, 0.5588235294117647, 'X[7] <= 0.996\ngini = 0.56\nsamples = 5\nvalue = [0, 1, 0, 3, 1, 0]'),
#  Text(0.648578811369509, 0.5, 'X[2] <= 0.145\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 0, 3, 0, 0]'),
#  Text(0.6444444444444445, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.6527131782945736, 0.4411764705882353, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.6568475452196383, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.6878552971576227, 0.6764705882352942, 'X[5] <= 41.25\ngini = 0.338\nsamples = 61\nvalue = [0, 0, 6, 49, 5, 1]'),
#  Text(0.6837209302325581, 0.6176470588235294, 'X[4] <= 0.058\ngini = 0.316\nsamples = 60\nvalue = [0, 0, 6, 49, 5, 0]'),
#  Text(0.6733850129198966, 0.5588235294117647, 'X[5] <= 14.0\ngini = 0.475\nsamples = 18\nvalue = [0, 0, 5, 12, 1, 0]'),
#  Text(0.6651162790697674, 0.5, 'X[2] <= 0.305\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 4, 2, 0, 0]'),
#  Text(0.6609819121447028, 0.4411764705882353, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.6692506459948321, 0.4411764705882353, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.6816537467700259, 0.5, 'X[10] <= 12.9\ngini = 0.292\nsamples = 12\nvalue = [0, 0, 1, 10, 1, 0]'),
#  Text(0.6775193798449612, 0.4411764705882353, 'X[6] <= 97.0\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 0, 10, 1, 0]'),
#  Text(0.6733850129198966, 0.38235294117647056, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9, 0, 0]'),
#  Text(0.6816537467700259, 0.38235294117647056, 'X[1] <= 0.33\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.6775193798449612, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.6857881136950904, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.6857881136950904, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.6940568475452197, 0.5588235294117647, 'X[9] <= 0.605\ngini = 0.214\nsamples = 42\nvalue = [0, 0, 1, 37, 4, 0]'),
#  Text(0.689922480620155, 0.5, 'gini = 0.0\nsamples = 24\nvalue = [0, 0, 0, 24, 0, 0]'),
#  Text(0.6981912144702842, 0.5, 'X[10] <= 12.35\ngini = 0.426\nsamples = 18\nvalue = [0, 0, 1, 13, 4, 0]'),
#  Text(0.6940568475452197, 0.4411764705882353, 'X[7] <= 0.995\ngini = 0.58\nsamples = 10\nvalue = [0, 0, 1, 5, 4, 0]'),
#  Text(0.689922480620155, 0.38235294117647056, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.6981912144702842, 0.38235294117647056, 'X[1] <= 0.46\ngini = 0.531\nsamples = 8\nvalue = [0, 0, 1, 5, 2, 0]'),
#  Text(0.6940568475452197, 0.3235294117647059, 'X[0] <= 10.1\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 1, 1, 2, 0]'),
#  Text(0.689922480620155, 0.2647058823529412, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.6981912144702842, 0.2647058823529412, 'X[4] <= 0.08\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.6940568475452197, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.7023255813953488, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.7023255813953488, 0.3235294117647059, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.7023255813953488, 0.4411764705882353, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(0.6919896640826874, 0.6176470588235294, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.7188630490956073, 0.7352941176470589, 'X[2] <= 0.405\ngini = 0.627\nsamples = 13\nvalue = [0, 2, 1, 3, 7, 0]'),
#  Text(0.710594315245478, 0.6764705882352942, 'X[5] <= 9.5\ngini = 0.64\nsamples = 5\nvalue = [0, 2, 1, 2, 0, 0]'),
#  Text(0.7064599483204135, 0.6176470588235294, 'X[4] <= 0.067\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1, 0, 0, 0]'),
#  Text(0.7023255813953488, 0.5588235294117647, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.710594315245478, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.7147286821705426, 0.6176470588235294, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.7271317829457364, 0.6764705882352942, 'X[4] <= 0.106\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 0, 1, 7, 0]'),
#  Text(0.7229974160206718, 0.6176470588235294, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 0, 7, 0]'),
#  Text(0.7312661498708011, 0.6176470588235294, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9101582687338501, 0.8529411764705882, 'X[10] <= 12.05\ngini = 0.617\nsamples = 201\nvalue = [0, 0, 22, 98, 73, 8]'),
#  Text(0.8389211886304909, 0.7941176470588235, 'X[1] <= 0.335\ngini = 0.589\nsamples = 164\nvalue = [0, 0, 21, 90, 50, 3]'),
#  Text(0.7674418604651163, 0.7352941176470589, 'X[9] <= 0.735\ngini = 0.59\nsamples = 50\nvalue = [0, 0, 5, 18, 26, 1]'),
#  Text(0.7478036175710594, 0.6764705882352942, 'X[5] <= 10.5\ngini = 0.5\nsamples = 12\nvalue = [0, 0, 2, 8, 2, 0]'),
#  Text(0.7395348837209302, 0.6176470588235294, 'X[6] <= 14.0\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 2, 1, 1, 0]'),
#  Text(0.7354005167958656, 0.5588235294117647, 'X[7] <= 0.995\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.7312661498708011, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.7395348837209302, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.7436692506459949, 0.5588235294117647, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.7560723514211887, 0.6176470588235294, 'X[0] <= 12.1\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 0, 7, 1, 0]'),
#  Text(0.751937984496124, 0.5588235294117647, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.7602067183462532, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.7870801033591731, 0.6764705882352942, 'X[10] <= 10.4\ngini = 0.525\nsamples = 38\nvalue = [0, 0, 3, 10, 24, 1]'),
#  Text(0.772609819121447, 0.6176470588235294, 'X[5] <= 36.5\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 0, 5, 1, 0]'),
#  Text(0.7684754521963825, 0.5588235294117647, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.7767441860465116, 0.5588235294117647, 'X[7] <= 0.998\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.772609819121447, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.7808785529715763, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8015503875968992, 0.6176470588235294, 'X[4] <= 0.12\ngini = 0.449\nsamples = 32\nvalue = [0, 0, 3, 5, 23, 1]'),
#  Text(0.7974160206718346, 0.5588235294117647, 'X[6] <= 53.5\ngini = 0.391\nsamples = 30\nvalue = [0, 0, 3, 3, 23, 1]'),
#  Text(0.7891472868217054, 0.5, 'X[3] <= 1.65\ngini = 0.288\nsamples = 24\nvalue = [0, 0, 0, 3, 20, 1]'),
#  Text(0.7850129198966408, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.7932816537467701, 0.4411764705882353, 'X[5] <= 6.5\ngini = 0.234\nsamples = 23\nvalue = [0, 0, 0, 2, 20, 1]'),
#  Text(0.7891472868217054, 0.38235294117647056, 'X[10] <= 11.45\ngini = 0.494\nsamples = 9\nvalue = [0, 0, 0, 2, 6, 1]'),
#  Text(0.7850129198966408, 0.3235294117647059, 'X[8] <= 3.255\ngini = 0.375\nsamples = 8\nvalue = [0, 0, 0, 2, 6, 0]'),
#  Text(0.7808785529715763, 0.2647058823529412, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0]'),
#  Text(0.7891472868217054, 0.2647058823529412, 'X[6] <= 21.5\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 2, 1, 0]'),
#  Text(0.7850129198966408, 0.20588235294117646, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.7932816537467701, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.7932816537467701, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.7974160206718346, 0.38235294117647056, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 0, 0, 14, 0]'),
#  Text(0.8056847545219639, 0.5, 'X[6] <= 72.0\ngini = 0.5\nsamples = 6\nvalue = [0, 0, 3, 0, 3, 0]'),
#  Text(0.8015503875968992, 0.4411764705882353, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.8098191214470284, 0.4411764705882353, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.8056847545219639, 0.5588235294117647, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.9104005167958656, 0.7352941176470589, 'X[3] <= 4.4\ngini = 0.537\nsamples = 114\nvalue = [0, 0, 16, 72, 24, 2]'),
#  Text(0.8869509043927648, 0.6764705882352942, 'X[2] <= 0.56\ngini = 0.484\nsamples = 104\nvalue = [0, 0, 10, 71, 21, 2]'),
#  Text(0.8710594315245478, 0.6176470588235294, 'X[1] <= 0.875\ngini = 0.431\nsamples = 90\nvalue = [0, 0, 9, 66, 13, 2]'),
#  Text(0.8669250645994832, 0.5588235294117647, 'X[4] <= 0.071\ngini = 0.409\nsamples = 88\nvalue = [0, 0, 7, 66, 13, 2]'),
#  Text(0.8537467700258398, 0.5, 'X[1] <= 0.555\ngini = 0.542\nsamples = 34\nvalue = [0, 0, 2, 21, 9, 2]'),
#  Text(0.8397932816537468, 0.4411764705882353, 'X[6] <= 47.5\ngini = 0.464\nsamples = 27\nvalue = [0, 0, 1, 19, 5, 2]'),
#  Text(0.8242894056847545, 0.38235294117647056, 'X[7] <= 0.996\ngini = 0.602\nsamples = 16\nvalue = [0, 0, 1, 9, 4, 2]'),
#  Text(0.813953488372093, 0.3235294117647059, 'X[2] <= 0.285\ngini = 0.716\nsamples = 9\nvalue = [0, 0, 1, 3, 3, 2]'),
#  Text(0.8056847545219639, 0.2647058823529412, 'X[3] <= 2.15\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 1, 3, 0, 0]'),
#  Text(0.8015503875968992, 0.20588235294117646, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.8098191214470284, 0.20588235294117646, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8222222222222222, 0.2647058823529412, 'X[10] <= 11.25\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 0, 0, 3, 2]'),
#  Text(0.8180878552971577, 0.20588235294117646, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.8263565891472868, 0.20588235294117646, 'X[3] <= 2.1\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 0, 1, 2]'),
#  Text(0.8222222222222222, 0.14705882352941177, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2]'),
#  Text(0.8304909560723515, 0.14705882352941177, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.834625322997416, 0.3235294117647059, 'X[6] <= 33.0\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 0, 6, 1, 0]'),
#  Text(0.8304909560723515, 0.2647058823529412, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.8387596899224806, 0.2647058823529412, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.8552971576227391, 0.38235294117647056, 'X[5] <= 21.5\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 0, 10, 1, 0]'),
#  Text(0.8511627906976744, 0.3235294117647059, 'X[2] <= 0.405\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.8470284237726098, 0.2647058823529412, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.8552971576227391, 0.2647058823529412, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8594315245478036, 0.3235294117647059, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9, 0, 0]'),
#  Text(0.8677002583979329, 0.4411764705882353, 'X[4] <= 0.061\ngini = 0.571\nsamples = 7\nvalue = [0, 0, 1, 2, 4, 0]'),
#  Text(0.8635658914728682, 0.38235294117647056, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.8718346253229974, 0.38235294117647056, 'X[2] <= 0.33\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 1, 0, 4, 0]'),
#  Text(0.8677002583979329, 0.3235294117647059, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(0.875968992248062, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8801033591731267, 0.5, 'X[1] <= 0.345\ngini = 0.291\nsamples = 54\nvalue = [0, 0, 5, 45, 4, 0]'),
#  Text(0.875968992248062, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8842377260981912, 0.4411764705882353, 'X[0] <= 6.0\ngini = 0.268\nsamples = 53\nvalue = [0, 0, 4, 45, 4, 0]'),
#  Text(0.8801033591731267, 0.38235294117647056, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8883720930232558, 0.38235294117647056, 'X[0] <= 14.25\ngini = 0.242\nsamples = 52\nvalue = [0, 0, 3, 45, 4, 0]'),
#  Text(0.8842377260981912, 0.3235294117647059, 'X[9] <= 0.845\ngini = 0.214\nsamples = 51\nvalue = [0, 0, 2, 45, 4, 0]'),
#  Text(0.8697674418604651, 0.2647058823529412, 'X[4] <= 0.123\ngini = 0.141\nsamples = 40\nvalue = [0, 0, 1, 37, 2, 0]'),
#  Text(0.8614987080103359, 0.20588235294117646, 'X[10] <= 11.65\ngini = 0.1\nsamples = 38\nvalue = [0, 0, 0, 36, 2, 0]'),
#  Text(0.8573643410852713, 0.14705882352941177, 'gini = 0.0\nsamples = 31\nvalue = [0, 0, 0, 31, 0, 0]'),
#  Text(0.8656330749354005, 0.14705882352941177, 'X[10] <= 11.85\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 0, 5, 2, 0]'),
#  Text(0.8614987080103359, 0.08823529411764706, 'X[0] <= 7.3\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]'),
#  Text(0.8573643410852713, 0.029411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8656330749354005, 0.029411764705882353, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.8697674418604651, 0.08823529411764706, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.8780361757105943, 0.20588235294117646, 'X[9] <= 0.755\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.8739018087855297, 0.14705882352941177, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8821705426356589, 0.14705882352941177, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8987080103359173, 0.2647058823529412, 'X[9] <= 0.885\ngini = 0.43\nsamples = 11\nvalue = [0, 0, 1, 8, 2, 0]'),
#  Text(0.8945736434108527, 0.20588235294117646, 'X[8] <= 3.305\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 1, 1, 2, 0]'),
#  Text(0.8904392764857881, 0.14705882352941177, 'X[7] <= 0.998\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.8863049095607235, 0.08823529411764706, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8945736434108527, 0.08823529411764706, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8987080103359173, 0.14705882352941177, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.9028423772609819, 0.20588235294117646, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.8925064599483205, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8751937984496124, 0.5588235294117647, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.9028423772609819, 0.6176470588235294, 'X[7] <= 0.998\ngini = 0.541\nsamples = 14\nvalue = [0, 0, 1, 5, 8, 0]'),
#  Text(0.8925064599483205, 0.5588235294117647, 'X[4] <= 0.147\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 0, 1, 6, 0]'),
#  Text(0.8883720930232558, 0.5, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 0, 6, 0]'),
#  Text(0.896640826873385, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9131782945736434, 0.5588235294117647, 'X[10] <= 10.65\ngini = 0.571\nsamples = 7\nvalue = [0, 0, 1, 4, 2, 0]'),
#  Text(0.9049095607235143, 0.5, 'X[6] <= 47.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(0.9007751937984496, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9090439276485788, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9214470284237726, 0.5, 'X[8] <= 2.98\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 0, 4, 1, 0]'),
#  Text(0.917312661498708, 0.4411764705882353, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9255813953488372, 0.4411764705882353, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.9338501291989664, 0.6764705882352942, 'X[6] <= 52.5\ngini = 0.54\nsamples = 10\nvalue = [0, 0, 6, 1, 3, 0]'),
#  Text(0.9297157622739018, 0.6176470588235294, 'X[2] <= 0.45\ngini = 0.56\nsamples = 5\nvalue = [0, 0, 1, 1, 3, 0]'),
#  Text(0.9255813953488372, 0.5588235294117647, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.9338501291989664, 0.5588235294117647, 'X[6] <= 15.0\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.9297157622739018, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.937984496124031, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.937984496124031, 0.6176470588235294, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.9813953488372092, 0.7941176470588235, 'X[9] <= 0.905\ngini = 0.548\nsamples = 37\nvalue = [0, 0, 1, 8, 23, 5]'),
#  Text(0.9772609819121447, 0.7352941176470589, 'X[10] <= 13.8\ngini = 0.498\nsamples = 34\nvalue = [0, 0, 1, 5, 23, 5]'),
#  Text(0.9627906976744186, 0.6764705882352942, 'X[2] <= 0.565\ngini = 0.4\nsamples = 29\nvalue = [0, 0, 1, 2, 22, 4]'),
#  Text(0.9545219638242894, 0.6176470588235294, 'X[5] <= 31.5\ngini = 0.313\nsamples = 27\nvalue = [0, 0, 0, 1, 22, 4]'),
#  Text(0.9503875968992248, 0.5588235294117647, 'X[3] <= 6.3\ngini = 0.269\nsamples = 26\nvalue = [0, 0, 0, 1, 22, 3]'),
#  Text(0.9462532299741602, 0.5, 'X[4] <= 0.076\ngini = 0.218\nsamples = 25\nvalue = [0, 0, 0, 1, 22, 2]'),
#  Text(0.937984496124031, 0.4411764705882353, 'X[9] <= 0.705\ngini = 0.1\nsamples = 19\nvalue = [0, 0, 0, 1, 18, 0]'),
#  Text(0.9338501291989664, 0.38235294117647056, 'X[7] <= 0.995\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]'),
#  Text(0.9297157622739018, 0.3235294117647059, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.937984496124031, 0.3235294117647059, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9421188630490956, 0.38235294117647056, 'gini = 0.0\nsamples = 16\nvalue = [0, 0, 0, 0, 16, 0]'),
#  Text(0.9545219638242894, 0.4411764705882353, 'X[0] <= 7.95\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 0, 0, 4, 2]'),
#  Text(0.9503875968992248, 0.38235294117647056, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2]'),
#  Text(0.958656330749354, 0.38235294117647056, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(0.9545219638242894, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.958656330749354, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.9710594315245478, 0.6176470588235294, 'X[3] <= 3.4\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.9669250645994832, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9751937984496124, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.9917312661498708, 0.6764705882352942, 'X[1] <= 0.475\ngini = 0.56\nsamples = 5\nvalue = [0, 0, 0, 3, 1, 1]'),
#  Text(0.9875968992248062, 0.6176470588235294, 'X[8] <= 3.705\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 3, 1, 0]'),
#  Text(0.9834625322997416, 0.5588235294117647, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.9917312661498708, 0.5588235294117647, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9958656330749354, 0.6176470588235294, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.9855297157622739, 0.7352941176470589, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]')]

# %%
fig.savefig("decistion_tree_classifier.png")

# %%
y_predict=model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_predict)
# Out:
# 0.49443207126948774

# %%
grid_param = {
    'criterion': ['gini', 'entropy'],
    'max_depth' : range(2,10,1),
    'min_samples_leaf' : range(1,8,1),
    'min_samples_split': range(2,8,1),
    'splitter' : ['best', 'random']
    
}

# %%
from sklearn.model_selection import GridSearchCV
grid_searh=GridSearchCV(estimator=model,param_grid=grid_param,cv=3,verbose=1)

# %%
grid_searh.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 1344 candidates, totalling 4032 fits
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(2, 10),
#                          'min_samples_leaf': range(1, 8),
#                          'min_samples_split': range(2, 8),
#                          'splitter': ['best', 'random']},
#              verbose=1)

# %%
grid_searh.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 5,
#  'min_samples_leaf': 7,
#  'min_samples_split': 7,
#  'splitter': 'random'}

# %%
model_with_best_params=DecisionTreeClassifier(criterion= 'entropy',max_depth= 6,min_samples_leaf= 6,min_samples_split= 5,splitter='random')

# %%
model_with_best_params.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=6, min_samples_leaf=6,
#                        min_samples_split=5, splitter='random')

# %%
from sklearn import tree
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(25,15))
tree.plot_tree(model_with_best_params,filled=True,fontsize=10)
# Out:
# [Text(0.6675, 0.9285714285714286, 'X[10] <= 12.077\nentropy = 1.721\nsamples = 910\nvalue = [7, 31, 389, 359, 114, 10]'),
#  Text(0.41833333333333333, 0.7857142857142857, 'X[10] <= 10.472\nentropy = 1.65\nsamples = 824\nvalue = [7, 31, 382, 320, 79, 5]'),
#  Text(0.21333333333333335, 0.6428571428571429, 'X[6] <= 40.831\nentropy = 1.319\nsamples = 524\nvalue = [4, 16, 318, 171, 15, 0]'),
#  Text(0.10666666666666667, 0.5, 'X[9] <= 0.524\nentropy = 1.404\nsamples = 217\nvalue = [2, 6, 110, 91, 8, 0]'),
#  Text(0.05333333333333334, 0.35714285714285715, 'X[9] <= 0.473\nentropy = 1.158\nsamples = 47\nvalue = [1, 5, 35, 6, 0, 0]'),
#  Text(0.02666666666666667, 0.21428571428571427, 'X[10] <= 9.841\nentropy = 0.629\nsamples = 19\nvalue = [0, 3, 16, 0, 0, 0]'),
#  Text(0.013333333333333334, 0.07142857142857142, 'entropy = 0.811\nsamples = 12\nvalue = [0, 3, 9, 0, 0, 0]'),
#  Text(0.04, 0.07142857142857142, 'entropy = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.08, 0.21428571428571427, 'X[8] <= 3.282\nentropy = 1.299\nsamples = 28\nvalue = [1, 2, 19, 6, 0, 0]'),
#  Text(0.06666666666666667, 0.07142857142857142, 'entropy = 0.863\nsamples = 14\nvalue = [0, 0, 10, 4, 0, 0]'),
#  Text(0.09333333333333334, 0.07142857142857142, 'entropy = 1.484\nsamples = 14\nvalue = [1, 2, 9, 2, 0, 0]'),
#  Text(0.16, 0.35714285714285715, 'X[6] <= 18.465\nentropy = 1.316\nsamples = 170\nvalue = [1, 1, 75, 85, 8, 0]'),
#  Text(0.13333333333333333, 0.21428571428571427, 'X[9] <= 0.745\nentropy = 1.269\nsamples = 40\nvalue = [1, 1, 16, 22, 0, 0]'),
#  Text(0.12, 0.07142857142857142, 'entropy = 1.261\nsamples = 32\nvalue = [1, 1, 10, 20, 0, 0]'),
#  Text(0.14666666666666667, 0.07142857142857142, 'entropy = 0.811\nsamples = 8\nvalue = [0, 0, 6, 2, 0, 0]'),
#  Text(0.18666666666666668, 0.21428571428571427, 'X[9] <= 0.679\nentropy = 1.271\nsamples = 130\nvalue = [0, 0, 59, 63, 8, 0]'),
#  Text(0.17333333333333334, 0.07142857142857142, 'entropy = 1.162\nsamples = 90\nvalue = [0, 0, 50, 37, 3, 0]'),
#  Text(0.2, 0.07142857142857142, 'entropy = 1.263\nsamples = 40\nvalue = [0, 0, 9, 26, 5, 0]'),
#  Text(0.32, 0.5, 'X[6] <= 70.039\nentropy = 1.219\nsamples = 307\nvalue = [2, 10, 208, 80, 7, 0]'),
#  Text(0.26666666666666666, 0.35714285714285715, 'X[0] <= 8.588\nentropy = 1.504\nsamples = 161\nvalue = [2, 8, 86, 58, 7, 0]'),
#  Text(0.24, 0.21428571428571427, 'X[10] <= 10.09\nentropy = 1.21\nsamples = 108\nvalue = [0, 4, 65, 38, 1, 0]'),
#  Text(0.22666666666666666, 0.07142857142857142, 'entropy = 1.137\nsamples = 82\nvalue = [0, 3, 56, 22, 1, 0]'),
#  Text(0.25333333333333335, 0.07142857142857142, 'entropy = 1.142\nsamples = 26\nvalue = [0, 1, 9, 16, 0, 0]'),
#  Text(0.29333333333333333, 0.21428571428571427, 'X[10] <= 9.793\nentropy = 1.875\nsamples = 53\nvalue = [2, 4, 21, 20, 6, 0]'),
#  Text(0.28, 0.07142857142857142, 'entropy = 1.817\nsamples = 25\nvalue = [1, 4, 12, 7, 1, 0]'),
#  Text(0.30666666666666664, 0.07142857142857142, 'entropy = 1.656\nsamples = 28\nvalue = [1, 0, 9, 13, 5, 0]'),
#  Text(0.37333333333333335, 0.35714285714285715, 'X[7] <= 0.998\nentropy = 0.713\nsamples = 146\nvalue = [0, 2, 122, 22, 0, 0]'),
#  Text(0.3466666666666667, 0.21428571428571427, 'X[7] <= 0.996\nentropy = 0.864\nsamples = 79\nvalue = [0, 2, 62, 15, 0, 0]'),
#  Text(0.3333333333333333, 0.07142857142857142, 'entropy = 0.439\nsamples = 22\nvalue = [0, 0, 20, 2, 0, 0]'),
#  Text(0.36, 0.07142857142857142, 'entropy = 0.981\nsamples = 57\nvalue = [0, 2, 42, 13, 0, 0]'),
#  Text(0.4, 0.21428571428571427, 'X[4] <= 0.099\nentropy = 0.483\nsamples = 67\nvalue = [0, 0, 60, 7, 0, 0]'),
#  Text(0.38666666666666666, 0.07142857142857142, 'entropy = 0.584\nsamples = 50\nvalue = [0, 0, 43, 7, 0, 0]'),
#  Text(0.41333333333333333, 0.07142857142857142, 'entropy = 0.0\nsamples = 17\nvalue = [0, 0, 17, 0, 0, 0]'),
#  Text(0.6233333333333333, 0.6428571428571429, 'X[9] <= 0.665\nentropy = 1.833\nsamples = 300\nvalue = [3, 15, 64, 149, 64, 5]'),
#  Text(0.5333333333333333, 0.5, 'X[10] <= 11.456\nentropy = 1.884\nsamples = 150\nvalue = [3, 14, 46, 70, 15, 2]'),
#  Text(0.48, 0.35714285714285715, 'X[2] <= 0.063\nentropy = 1.884\nsamples = 107\nvalue = [3, 11, 43, 41, 8, 1]'),
#  Text(0.4533333333333333, 0.21428571428571427, 'X[2] <= 0.011\nentropy = 2.125\nsamples = 34\nvalue = [3, 7, 9, 12, 3, 0]'),
#  Text(0.44, 0.07142857142857142, 'entropy = 2.005\nsamples = 22\nvalue = [2, 2, 8, 8, 2, 0]'),
#  Text(0.4666666666666667, 0.07142857142857142, 'entropy = 1.951\nsamples = 12\nvalue = [1, 5, 1, 4, 1, 0]'),
#  Text(0.5066666666666667, 0.21428571428571427, 'X[2] <= 0.288\nentropy = 1.622\nsamples = 73\nvalue = [0, 4, 34, 29, 5, 1]'),
#  Text(0.49333333333333335, 0.07142857142857142, 'entropy = 1.447\nsamples = 27\nvalue = [0, 4, 13, 10, 0, 0]'),
#  Text(0.52, 0.07142857142857142, 'entropy = 1.511\nsamples = 46\nvalue = [0, 0, 21, 19, 5, 1]'),
#  Text(0.5866666666666667, 0.35714285714285715, 'X[7] <= 0.995\nentropy = 1.472\nsamples = 43\nvalue = [0, 3, 3, 29, 7, 1]'),
#  Text(0.56, 0.21428571428571427, 'X[5] <= 13.809\nentropy = 1.116\nsamples = 26\nvalue = [0, 0, 2, 20, 3, 1]'),
#  Text(0.5466666666666666, 0.07142857142857142, 'entropy = 1.199\nsamples = 16\nvalue = [0, 0, 2, 11, 3, 0]'),
#  Text(0.5733333333333334, 0.07142857142857142, 'entropy = 0.469\nsamples = 10\nvalue = [0, 0, 0, 9, 0, 1]'),
#  Text(0.6133333333333333, 0.21428571428571427, 'X[10] <= 11.772\nentropy = 1.659\nsamples = 17\nvalue = [0, 3, 1, 9, 4, 0]'),
#  Text(0.6, 0.07142857142857142, 'entropy = 1.379\nsamples = 7\nvalue = [0, 2, 0, 4, 1, 0]'),
#  Text(0.6266666666666667, 0.07142857142857142, 'entropy = 1.685\nsamples = 10\nvalue = [0, 1, 1, 5, 3, 0]'),
#  Text(0.7133333333333334, 0.5, 'X[2] <= 0.142\nentropy = 1.543\nsamples = 150\nvalue = [0, 1, 18, 79, 49, 3]'),
#  Text(0.68, 0.35714285714285715, 'X[3] <= 2.32\nentropy = 1.206\nsamples = 24\nvalue = [0, 1, 1, 17, 5, 0]'),
#  Text(0.6666666666666666, 0.21428571428571427, 'X[10] <= 11.303\nentropy = 0.64\nsamples = 17\nvalue = [0, 0, 1, 15, 1, 0]'),
#  Text(0.6533333333333333, 0.07142857142857142, 'entropy = 0.0\nsamples = 10\nvalue = [0, 0, 0, 10, 0, 0]'),
#  Text(0.68, 0.07142857142857142, 'entropy = 1.149\nsamples = 7\nvalue = [0, 0, 1, 5, 1, 0]'),
#  Text(0.6933333333333334, 0.21428571428571427, 'entropy = 1.379\nsamples = 7\nvalue = [0, 1, 0, 2, 4, 0]'),
#  Text(0.7466666666666667, 0.35714285714285715, 'X[1] <= 0.448\nentropy = 1.552\nsamples = 126\nvalue = [0, 0, 17, 62, 44, 3]'),
#  Text(0.72, 0.21428571428571427, 'X[10] <= 11.295\nentropy = 1.611\nsamples = 88\nvalue = [0, 0, 12, 37, 36, 3]'),
#  Text(0.7066666666666667, 0.07142857142857142, 'entropy = 1.484\nsamples = 51\nvalue = [0, 0, 9, 18, 24, 0]'),
#  Text(0.7333333333333333, 0.07142857142857142, 'entropy = 1.608\nsamples = 37\nvalue = [0, 0, 3, 19, 12, 3]'),
#  Text(0.7733333333333333, 0.21428571428571427, 'X[10] <= 11.597\nentropy = 1.256\nsamples = 38\nvalue = [0, 0, 5, 25, 8, 0]'),
#  Text(0.76, 0.07142857142857142, 'entropy = 1.27\nsamples = 32\nvalue = [0, 0, 5, 21, 6, 0]'),
#  Text(0.7866666666666666, 0.07142857142857142, 'entropy = 0.918\nsamples = 6\nvalue = [0, 0, 0, 4, 2, 0]'),
#  Text(0.9166666666666666, 0.7857142857142857, 'X[9] <= 0.724\nentropy = 1.578\nsamples = 86\nvalue = [0, 0, 7, 39, 35, 5]'),
#  Text(0.86, 0.6428571428571429, 'X[2] <= 0.338\nentropy = 1.432\nsamples = 56\nvalue = [0, 0, 6, 32, 17, 1]'),
#  Text(0.8266666666666667, 0.5, 'X[7] <= 0.994\nentropy = 1.35\nsamples = 31\nvalue = [0, 0, 6, 19, 6, 0]'),
#  Text(0.8133333333333334, 0.35714285714285715, 'X[10] <= 12.506\nentropy = 1.449\nsamples = 22\nvalue = [0, 0, 5, 12, 5, 0]'),
#  Text(0.8, 0.21428571428571427, 'entropy = 1.157\nsamples = 10\nvalue = [0, 0, 1, 7, 2, 0]'),
#  Text(0.8266666666666667, 0.21428571428571427, 'entropy = 1.555\nsamples = 12\nvalue = [0, 0, 4, 5, 3, 0]'),
#  Text(0.84, 0.35714285714285715, 'entropy = 0.986\nsamples = 9\nvalue = [0, 0, 1, 7, 1, 0]'),
#  Text(0.8933333333333333, 0.5, 'X[1] <= 0.317\nentropy = 1.197\nsamples = 25\nvalue = [0, 0, 0, 13, 11, 1]'),
#  Text(0.8666666666666667, 0.35714285714285715, 'X[4] <= 0.058\nentropy = 0.98\nsamples = 12\nvalue = [0, 0, 0, 5, 7, 0]'),
#  Text(0.8533333333333334, 0.21428571428571427, 'entropy = 0.918\nsamples = 6\nvalue = [0, 0, 0, 2, 4, 0]'),
#  Text(0.88, 0.21428571428571427, 'entropy = 1.0\nsamples = 6\nvalue = [0, 0, 0, 3, 3, 0]'),
#  Text(0.92, 0.35714285714285715, 'X[7] <= 0.995\nentropy = 1.239\nsamples = 13\nvalue = [0, 0, 0, 8, 4, 1]'),
#  Text(0.9066666666666666, 0.21428571428571427, 'entropy = 1.379\nsamples = 7\nvalue = [0, 0, 0, 4, 2, 1]'),
#  Text(0.9333333333333333, 0.21428571428571427, 'entropy = 0.918\nsamples = 6\nvalue = [0, 0, 0, 4, 2, 0]'),
#  Text(0.9733333333333334, 0.6428571428571429, 'X[1] <= 0.459\nentropy = 1.483\nsamples = 30\nvalue = [0, 0, 1, 7, 18, 4]'),
#  Text(0.96, 0.5, 'X[2] <= 0.36\nentropy = 1.122\nsamples = 18\nvalue = [0, 0, 0, 3, 13, 2]'),
#  Text(0.9466666666666667, 0.35714285714285715, 'entropy = 0.918\nsamples = 6\nvalue = [0, 0, 0, 2, 4, 0]'),
#  Text(0.9733333333333334, 0.35714285714285715, 'entropy = 1.041\nsamples = 12\nvalue = [0, 0, 0, 1, 9, 2]'),
#  Text(0.9866666666666667, 0.5, 'entropy = 1.784\nsamples = 12\nvalue = [0, 0, 1, 4, 5, 2]')]

# %%
y_prediction2=model_with_best_params.predict(X_test)

# %%
accuracy_score(y_test,y_prediction2)
# Out:
# 0.534521158129176

# %%
#logistic regression, SVM ,  going forward(RF,XB,GB,AB)

# %%
#Implement the decision tree regressor
dataset:https://archive.ics.uci.edu/ml/datasets/individual+household+electric+power+consumption
        
take_refrence_from_here:https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeRegressor.html#sklearn.tree.DecisionTreeRegressor

# %%
from sklearn.ensemble import RandomForestClassifier
Rf_model=RandomForestClassifier()

# %%
Rf_model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_rf=Rf_model.predict(X_test)

# %%
accuracy_score(y_test,y_pred_rf)
# Out:
# 0.6057906458797327

# %%
# we are tuning three hyperparameters right now, we are passing the different values for both parameters
grid_param = {
    "n_estimators" : [90,100,115,130],
    'criterion': ['gini', 'entropy'],
    'max_depth' : range(2,20,1),
    'min_samples_leaf' : range(1,10,1),
    'min_samples_split': range(2,10,1),
    'max_features' : ['auto','log2']
}

# %%
from sklearn.model_selection import GridSearchCV
grid_searh=GridSearchCV(estimator=Rf_model,param_grid=grid_param,cv=3,verbose=2,n_jobs=-1)

# %%
grid_searh.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 1344 candidates, totalling 4032 fits

# %%
grid_searh.best_params_

# %%
Rf_model_with_best_params=RandomForestClassifier(criterion='gini',max_depth= 14,max_features= 'log2',min_samples_leaf= 1,min_samples_split= 2,n_estimators=115)

# %%
Rf_model_with_best_params.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=14, max_features='log2', n_estimators=115)

# %%
y_predict_rf_bp=Rf_model_with_best_params.predict(X_test)

# %%
accuracy_score(y_test,y_predict_rf_bp)
# Out:
# 0.5991091314031181

# %%
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier
from sklearn.datasets import make_classification

model_bagging_svc = BaggingClassifier(base_estimator=SVC(),n_estimators=50, random_state=0).fit(X_train,y_train)

# %%
y_predict_bagging=model_bagging_svc.predict(X_test)

# %%
accuracy_score(y_test,y_predict_bagging)
# Out:
# 0.4766146993318486

# %%
#use bagging classiifer and regressor, extra tree classifier and regressor, voting classifer and regressor and random forest classifier and regressor on top of House hold consumpltion data and cencus data

data link: https://archive.ics.uci.edu/ml/datasets/individual+household+electric+power+consumption
        https://archive.ics.uci.edu/ml/datasets/census+income
    
sklearn_link:https://scikit-learn.org/stable/modules/classes.html#module-sklearn.ensemble
# Out:
#   Cell In [64], line 3
#     data link: https://archive.ics.uci.edu/ml/datasets/individual+household+electric+power+consumption
#          ^
# SyntaxError: invalid syntax

# %%
from sklearn.ensemble import AdaBoostClassifier
model=AdaBoostClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# AdaBoostClassifier()

# %%
y_predict_ada=model.predict(X_test)

# %%
accuracy_score(y_test,y_predict_ada)
# Out:
# 0.5211581291759465

# %%
### Hyperparameter tunning

# %%
grid_param = {
    "n_estimators" : [90,100,130,150],
    "learning_rate":[ 0.001,0.01,0.1,0.5],
   
}

# %%
from sklearn.model_selection import GridSearchCV
grid_searh=GridSearchCV(estimator=model,param_grid=grid_param,cv=3,verbose=2,n_jobs=-1)

# %%
grid_searh.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 1344 candidates, totalling 4032 fits

# %%
###best params:learning rate=0.05,n_estimators=150 
from sklearn.ensemble import AdaBoostClassifier
model=AdaBoostClassifier(learning_rate=0.05,n_estimators=150)

# %%
model.fit(X_train,y_train)
# Out:
# AdaBoostClassifier(learning_rate=0.05, n_estimators=150)

# %%
y_predict1=model.predict(X_test)

# %%
accuracy_score(y_test,y_predict1)
# Out:
# 0.5300668151447662

# %%
from sklearn.ensemble import AdaBoostRegressor
model1=AdaBoostRegressor()

# %%
model1.fit(X_train,y_train)
# Out:
# AdaBoostRegressor()

# %%
y_predict2=model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 y_predict2=model.predict(X_test)
#
# NameError: name 'model' is not defined

# %%
accuracy_score(y_test,y_predict1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 accuracy_score(y_test,y_predict1)
#
# NameError: name 'accuracy_score' is not defined

# %%
grid_param = {
    "n_estimators" : [90,100,130,150],
    "learning_rate":[ 0.001,0.01,0.1,0.5],

}

# %%
from sklearn.model_selection import GridSearchCV
grid_searh=GridSearchCV(estimator=model1,param_grid=grid_param,cv=3,verbose=2,n_jobs=-1)

grid_searh.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [4], line 2
#       1 from sklearn.model_selection import GridSearchCV
# ----> 2 grid_searh=GridSearchCV(estimator=model1,param_grid=grid_param,cv=3,verbose=2,n_jobs=-1)
#       4 grid_searh.fit(X_train,y_train)
#
# NameError: name 'model1' is not defined

# %%
from sklearn.ensemble import AdaBoostRegressor
model1=AdaBoostRegressor(learning_rate=0.05,n_estimators=150)
y_predict3=model1.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [7], line 3
#       1 from sklearn.ensemble import AdaBoostRegressor
#       2 model1=AdaBoostRegressor(learning_rate=0.05,n_estimators=150)
# ----> 3 y_predict3=model1.predict(X_test)
#
# NameError: name 'X_test' is not defined

# %%
from sklearn.metrics import mean_squared_erro

print(mean_squared_error(y_test,y_predict3))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [8], line 1
# ----> 1 from sklearn.metrics import mean_squared_erro
#       3 print(mean_squared_error(y_test,y_predict3))
#
# ImportError: cannot import name 'mean_squared_erro' from 'sklearn.metrics' (/opt/conda/lib/python3.10/site-packages/sklearn/metrics/__init__.py)
